# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pylplot as plt

#show examples of data
pose = [pose]
segment = [example]
silhouette = [shadow]
optical_flow = [optics]

#table of patient measurements
patient_anthropometrics = [data]
